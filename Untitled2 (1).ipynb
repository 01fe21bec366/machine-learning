# %%
def is_palindrome(string):

  reversed_string = string[::-1]
  return string == reversed_string

def main():
  string = input("Enter a string: ")

  if is_palindrome(string):
    print(string, "is a palindrome.")
  else:
    print(string, "is not a palindrome.")

if __name__ == "__main__":
  main()

# %%
def print_pattern(n):
  for i in range(n):
    for j in range(i+1):
      print("*", end="")
    print()

n = int(input("Enter the number of rows: "))
print_pattern(n)
# Out:
# Enter the number of rows: 5
# *
# **
# ***
# ****
# *****

# %%
def is_prime(n):

  if n <= 1:
    return False
  for i in range(2, int(n ** 0.5) + 1):
    if n % i == 0:
      return False
  return True

def is_divisible(n, primes):
    for p in primes:
     if n % p == 0:
      return True
    return False

def main():
  n = int(input("Enter a number: "))

  if is_prime(n):
    print(n, "is a prime number.")
  else:
    if is_divisible(n, [3, 7, 9, 11]):
      print(n, "is divisible by 3, 7, 9, or 11.")
    else:
      print(n, "is not divisible by 3, 7, 9, or 11.")

if __name__ == "__main__":
  main()
# Out:
# Enter a number: 9
# 9 is divisible by 3, 7, 9, or 11.

# %%
def main():

  numbers = []


  for i in range(10):
    number = int(input("Enter a number: "))
    numbers.append(number)


  odd_numbers = []
  even_numbers = []


  for number in numbers:
    if number % 2 == 1:
      odd_numbers.append(number)
    else:
      even_numbers.append(number)


  print("Odd numbers:", odd_numbers)
  print("Even numbers:", even_numbers)

if __name__ == "__main__":
  main()
# Out:
# Enter a number: 4
# Enter a number: 5
# Enter a number: 6
# Enter a number: 7
# Enter a number: 8
# Enter a number: 9
# Enter a number: 1
# Enter a number: 2
# Enter a number: 3
# Enter a number: 4
# Odd numbers: [5, 7, 9, 1, 3]
# Even numbers: [4, 6, 8, 2, 4]

# %% [markdown]
# video 52

# %% [markdown]
# linear regression-statistic model which helps us understand btw dependent and independent variable
#
# we can implement using:
# 1.   scikit learn-give accuracy
# 2.   stats model-we have several other variable like p.....
# we use scikit learn bcz it is easy to use

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,5,13,25,33,46]).reshape((-1,1))
y=np.array([3,6,9,15,14,18])

# %%
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR=LinearRegression()

# %%
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=SLR.predict(x)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE:", mse)
print("intercept:",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# MSE: 1.9984111148061932
# intercept: 4.254517237556811
# slope: [0.32091786]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x=np.array([])
y=np.array([])
for i in range (0,6):
  m= random.randint(1,25)
  n=random.randint(1,25)
  x=np.append(x,m)
  y=np.append(y,n)
print(x)
print(y)
x=x.reshape((-1,1))
# Out:
# [20. 19.  7. 12. 19.  2.]
# [ 9. 21. 15. 21. 25. 25.]

# %%
plt.scatter(x,y)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
SLR=LinearRegression()

# %%
SLR.fit(x,y)
# Out:
# LinearRegression()

# %%
pred=SLR.predict(x)

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y,pred)
plt.plot(x,pred,color='Red',marker='*')
print("MSE:", mse)
print("intercept:",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# MSE: 29.92548316397689
# intercept: 22.465630603705915
# slope: [-0.237896]

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/linear files.csv')
print(data)
# Out:
#     x  y
# 0   2  3
# 1   3  4
# 2   4  5
# 3   5  6
# 4   6  8
# 5   7  9
# 6   8  7
# 7   9  6
# 8  12  4
# 9  13  5

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/linear files.csv')
m=data['x'].values
n=data['y'].values
m=m.reshape((-1,1))
plt.scatter(m,n)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(m,n)
pred=SLR.predict(m)
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(n,pred)
plt.plot(m,pred,color='Red',marker= '*')

print("MSE:", mse)
print("intercept",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# MSE: 3.147394540942928
# intercept 5.20347394540943
# slope: [0.0719603]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data=pd.read_csv('/content/drive/MyDrive/pol.csv')
m=data['x1'].values
n=data['x2'].values
o=data['y'].values
print(m)
print(n)
print(o)
m=m.reshape(-1,1)
n=n.reshape(-1,1)
plt.scatter(m,n)
plt.xlabel("IV")
plt.ylabel("DV")
plt.show()
from sklearn.linear_model import LinearRegression
SLR=LinearRegression()
SLR.fit(m,n)
pred=SLR.predict(m)
from sklearn.metrics import mean_squared_error

mse=mean_squared_error(n,pred)
plt.plot(m,pred,color='Red',marker= '*')

print("MSE:", mse)
print("intercept",SLR.intercept_)
print("slope:",SLR.coef_)
# Out:
# [1 2 4 5 7 9 3]
# [3 4 5 6 8 7 5]
# [ 4  5  7  8  9 12  3]
# MSE: 0.3939264328485886
# intercept [2.9491018]
# slope: [[0.55988024]]
